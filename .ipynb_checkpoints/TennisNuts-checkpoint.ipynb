# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://www.directtennis.co.uk/tennis-rackets/babolat")

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup.find_all('div', class_='img-wrap')
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <title>Babolat | Direct Tennis</title>
# <meta content="7 days" name="revisit">
# <meta content="index,follow" name="robots">
# <meta content="General" name="rating"/>
# <meta content="Great prices and fast delivery on Babolat Pure Drive, Aero, Strike tennis rackets. Excellent customer service &amp; returns service. Same day despatch up to 5pm." name="description"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!-- Global site tag (gtag.js) - Google Ads: CONVERSION_ID -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=AW-1028970258"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push( arguments ); }
#         gtag( 'js', new Date() );
#
#         gtag( 'config', 'AW-1028970258' );
#     </script>
# <!-- Favicon -->
# ...
