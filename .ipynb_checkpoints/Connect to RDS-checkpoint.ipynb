# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine

# %%
endpoint = 'database-1.c3uumi0k2s9r.eu-west-2.rds.amazonaws.com'
username = 'admin'
password = 'adminadmin'
database = 'Data'

con = mysql.connector.connect(user=username, password=password, host=endpoint, database=database)

# %%
mycursor = con.cursor()

# %%
# mycursor.execute("CREATE TABLE tennisprod (`Product Name` VARCHAR(255), `Product Price` VARCHAR(255), `Old Price` VARCHAR(255), `Product Cat` VARCHAR(256), `Time Added` VARCHAR(256))")

# %%
df = pd.read_csv('data/direct_tennis_products.csv')
engine = create_engine("mysql+mysqlconnector://admin:adminadmin@database-1.c3uumi0k2s9r.eu-west-2.rds.amazonaws.com/Data")

# %%
df.to_sql(name='tennisprod', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File C:\Projects\Tennis Equipments Aggregator\venv\lib\site-packages\mysql\connector\connection_cext.py:706, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     705         query = query.encode("utf-8")
# --> 706     self._cmysql.query(
#     707         query,
#     708         raw=raw,
#     709         buffered=buffered,
#     710         raw_as_string=raw_as_string,
#     711         query_attrs=self.query_attrs,
#     712     )
#     713 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown column 'product_name' in 'field list'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...
